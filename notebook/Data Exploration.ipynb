# %%
import pandas as pd

# %%
harukiDf = pd.read_csv("../dataset/Haruki-Murakami-th.csv",header=None)
kafKaDf = pd.read_csv("../dataset/Kafka-Murakami-th.csv",header=None)
norwegianDf = pd.read_csv("../dataset/Norwegian-Murakami-th.csv",header=None)

# %%
print("Haruki Number of tweets: %d"%harukiDf.shape[0])
print("Kafka Number of tweets: %d"%kafKaDf.shape[0])
print("Norwegian Number of tweets: %d"%norwegianDf.shape[0])
# Out:
# Haruki Number of tweets: 1073
# Kafka Number of tweets: 11
# Norwegian Number of tweets: 165

# %%
print("Haruki Number of unique tweets: %d"%harukiDf[2].unique().shape[0])
print("Kafka Number of unique tweets: %d"%kafKaDf[2].unique().shape[0])
print("Norwegian Number of unique tweets: %d"%norwegianDf[2].unique().shape[0])
# Out:
# Haruki Number of unique tweets: 29
# Kafka Number of unique tweets: 5
# Norwegian Number of unique tweets: 21

# %% [markdown]
# ### Concatenate data to form one big array of tweets

# %%
df = pd.concat([harukiDf,kafKaDf,norwegianDf])

# %%
import re
def cleanText(text):
    stopwords = ['\r\n','RT']
    text = re.sub(r"http\S+", "", text)
    for stopword in stopwords:
        text = text.replace(stopword,'')
    
    return text
df[2] = df[2].apply(cleanText)

# %%
# %%time
import deepcut as dc
df['tokenized'] = df[2].apply(dc.tokenize)
# Out:
# Using TensorFlow backend.
# CPU times: user 3min 48s, sys: 9.73 s, total: 3min 58s
# Wall time: 1min 42s

# %%
df.to_csv("../dataset/combined_tokenized.csv")

# %%
tweets = df['tokenized'].values
#tweets = df['tokenized'].values

# %%
type(tweets)
# Out:
# numpy.ndarray

# %%
tweets.shape
# Out:
# (1249,)

# %%
tweets
# Out:
# array([ [' ', '@', 'CandideBooks', ':', ' ', 'สวัสดี', 'วัน', 'หยุด', ' ', 'ฟัง', 'เพลง', 'จาก', 'แผ่น', 'ไวนิล', 'ส่วน', 'ตัว', 'ของ', 'มูราคา', 'มิ', 'กัน', 'ค่ะ', ' ', 'เพลง', 'เหล่า', 'นี้', 'ไป', 'ปรากฏ', 'ใน', 'หนังสือ', 'ของ', 'เขา', 'หลาย', 'เล่ม', 'เลย', ' '],
#        [' ', '@', 'CandideBooks', ':', ' ', 'สวัสดี', 'วัน', 'หยุด', ' ', 'ฟัง', 'เพลง', 'จาก', 'แผ่น', 'ไวนิล', 'ส่วน', 'ตัว', 'ของ', 'มูราคา', 'มิ', 'กัน', 'ค่ะ', ' ', 'เพลง', 'เหล่า', 'นี้', 'ไป', 'ปรากฏ', 'ใน', 'หนังสือ', 'ของ', 'เขา', 'หลาย', 'เล่ม', 'เลย', ' '],
#        ['"', 'อย่า', 'ได้', 'เผา', 'ชีวิต', 'ตัว', 'เอง', 'ทิ้ง', 'ไป', 'ใน', 'การ', 'ฝืนใจ', 'ทำ', '"', ' ', '-', ' ', 'ด้วย', 'รัก', ' ', 'ความ', 'ตาย', ' ', 'หัวใจ', 'สลาย', '/', ' ', 'Haruki Murakami', ' '],
#        ...,
#        [' ', '@', 'ItsView_', ': ', '#JJProjcet', 'เก็บ', 'หนังสือ', ' ', 'norwegian', ' ', 'wood', ' ', 'ชื่อ', 'ไทย', ' ', '"', 'ด้วย', 'รัก', ' ', 'ความ', 'ตาย', ' ', 'และ', 'หัวใจ', 'สลาย', '"', ' ', 'เข้า', 'ลิสต์', ' ', '#แจบ', 'อม', 'อ่าน', ' ', 'อีก', 'เล่ม', 'ค่ะ', 'ปล.', 'เคย', 'เป็น', ' ', '#จิ', '…'],
#        [' ', '@Jinyoung_Books', ':', ' ', 'หนังสือ', 'ที่', 'เจบี', 'ถือ', 'อยู่', ' ', 'ฉบับ', 'แปล', 'ไทย', ' ', 'คือ', ' ', 'หนังสือ', 'ด้วย', 'รัก', ' ', 'ความ', 'ตาย', ' ', 'และ', 'หัวใจ', 'สลาย', 'ค่ะ', ' '],
#        [' ', '@', 'ItsView_', ': ', '#JJProjcet', 'เก็บ', 'หนังสือ', ' ', 'norwegian', ' ', 'wood', ' ', 'ชื่อ', 'ไทย', ' ', '"', 'ด้วย', 'รัก', ' ', 'ความ', 'ตาย', ' ', 'และ', 'หัวใจ', 'สลาย', '"', ' ', 'เข้า', 'ลิสต์', ' ', '#แจบ', 'อม', 'อ่าน', ' ', 'อีก', 'เล่ม', 'ค่ะ', 'ปล.', 'เคย', 'เป็น', ' ', '#จิ', '…']], dtype=object)

# %%
stopwords = [' ','"','ที่','เรา','กัน','อื่น',':','จะ','ได้','@','ว่า','_','-','ก็','เท่า','อื่น','นึง','..','ไม่','ทำ','มี','เป็น','อีก','นี้','ลืม']
words = [word for tweet in tweets for word in tweet if word not in stopwords]

# %%
len(words)
# Out:
# 24000

# %%
from collections import Counter
counts = Counter(words)
counts.most_common(400)
# Out:
# [('คิด', 1460),
#  ('อ่าน', 1402),
#  ('คน', 1380),
#  ('หนังสือ', 827),
#  ('Haruki Murakami', 789),
#  ('พูด', 757),
#  ('ญี่ปุ่น', 660),
#  ('ถ้า', 660),
#  ('คำคม', 658),
#  ('อัน', 658),
#  ('SaraUpdate', 657),
#  ('ความ', 513),
#  ('ให้', 510),
#  ('วัน', 461),
#  ('…', 395),
#  ('และ', 371),
#  ('—', 238),
#  ('@readery_co', 237),
#  ('ดี', 235),
#  ('ไป', 177),
#  ('ตาย', 171),
#  ('ด้วย', 168),
#  ('รัก', 168),
#  ('ใน', 162),
#  ('ตัว', 160),
#  ('หัวใจ', 152),
#  ('สลาย', 149),
#  ('มัน', 148),
#  ('เอง', 145),
#  ('บน', 144),
#  ('การ', 142),
#  ('คุณ', 142),
#  ('TPaperless', 141),
#  ('ผม', 141),
#  ('ถึง', 140),
#  ('ตอน', 140),
#  ('ทุก', 139),
#  ('ตา', 138),
#  ('รุ่ง', 138),
#  ('เช้า', 138),
#  ('เตียง', 138),
#  ('นอน', 138),
#  ('ช่วย', 138),
#  ('ไขลาน', 138),
#  ('เต็ม', 138),
#  ('บอก', 138),
#  ('กับ', 138),
#  ('ที่สุด', 138),
#  ('อยู่', 137),
#  ('Ha', 136),
#  ('แค่', 127),
#  ('เรื่อง', 118),
#  ('มากมาย', 108),
#  (',', 107),
#  ('ใด', 102),
#  ('ไหน', 101),
#  ('“', 101),
#  ('”', 101),
#  ('ไม่ว่า', 100),
#  ('ขนาด', 100),
#  ('เปิดใจ', 99),
#  ('ตรงไปตรงมา', 99),
#  ('ย่อม', 99),
#  ('เปิด', 99),
#  ('ปาก', 99),
#  ('จาก', 98),
#  ('จริง', 97),
#  ('มา', 96),
#  ('ค่ะ', 89),
#  ('หรือ', 86),
#  ('จน', 85),
#  ('ปรารถนา', 84),
#  ('ใจดี', 84),
#  ('เยียวยา', 84),
#  ('เศร้า', 84),
#  ('เฝ้า', 84),
#  ('มอง', 84),
#  ('จบ', 84),
#  ('เรียนรู้', 84),
#  ('Haruki Muraka', 83),
#  ('ไทย', 76),
#  ('สัญญา', 70),
#  ('ใคร', 66),
#  ('แล้ว', 61),
#  ('เคย', 60),
#  ('เล่ม', 56),
#  ('แต่', 55),
#  ('สัก', 52),
#  ('ของ', 49),
#  ('norwegian', 49),
#  ('wood', 49),
#  ('#แจบ', 49),
#  ('คือ', 43),
#  ('ชื่อ', 43),
#  ('เข้า', 42),
#  ('ItsView_', 41),
#  (': ', 41),
#  ('#JJProjcet', 41),
#  ('เก็บ', 41),
#  ('ลิสต์', 41),
#  ('อม', 41),
#  ('ปล.', 41),
#  ('#จิ', 41),
#  ('Haruki Murakami-', 38),
#  ('ใช้', 37),
#  ('#AfterParty', 37),
#  ('bowtylight', 37),
#  ('ต้อง', 36),
#  ('ฝัน', 36),
#  ('ผิด', 36),
#  ('หวัง', 36),
#  ('คำ', 36),
#  ('สุดท้าย', 36),
#  ('หาย', 36),
#  ('Pinball', 36),
#  ('1973', 36),
#  ('#Lifeis', 35),
#  ('ต่อ', 35),
#  ('@Jinyoung_Books', 35),
#  ('เจบี', 35),
#  ('ถือ', 35),
#  ('ฉบับ', 35),
#  ('แปล', 35),
#  ('เชื่อ', 34),
#  ('เถอะ', 34),
#  ('กาลเวลา', 34),
#  ('@bowtylight', 33),
#  ('ใ', 33),
#  ('the', 32),
#  ('มิ', 30),
#  ('เรียก', 28),
#  ('เพลง', 26),
#  ('ๆ', 26),
#  ('ร่วม', 26),
#  ('ชีวิต', 24),
#  ('เธอ', 22),
#  ('ผ่าน', 21),
#  ('นั่น', 21),
#  ('กลับ', 21),
#  ('หนึ่ง', 21),
#  ('เขียน', 20),
#  ('สิ่ง', 19),
#  ('ต่างๆ', 19),
#  ('เคลื่อน', 19),
#  ('โดย', 19),
#  ('จับ', 19),
#  ('เอา', 19),
#  ('ไว้', 19),
#  ('ล่ะ', 19),
#  ('วิถี', 19),
#  ('Hear', 19),
#  ('Wind', 19),
#  ('Sing', 19),
#  ('Dan_TripleP', 19),
#  ('เวลา', 19),
#  ('#Afte', 18),
#  ('ชอบ', 18),
#  ('อดีต', 18),
#  ('ห้วง', 18),
#  ('หายลับ', 18),
#  ('ร้องไห้', 18),
#  ('ปาน', 18),
#  ('อาจ', 18),
#  ('หวน', 18),
#  ('คืน', 18),
#  ('...', 18),
#  ('CandideBooks', 17),
#  ('Norwegian', 17),
#  ('Wood', 17),
#  ('ส่วน', 16),
#  ('นี่', 16),
#  ('งาน', 16),
#  ('มาก', 15),
#  ('เหล่า', 14),
#  ('เลย', 14),
#  ('รู้', 14),
#  ('สวัสดี', 13),
#  ('หยุด', 13),
#  ('ฟัง', 13),
#  ('แผ่น', 13),
#  ('ไวนิล', 13),
#  ('มูราคา', 13),
#  ('ปรากฏ', 13),
#  ('เขา', 13),
#  ('หลาย', 13),
#  ('ฉัน', 13),
#  ('SunnBlaze', 13),
#  ('ฮารูกิ', 13),
#  (' มูราคา', 13),
#  ('ง่าย', 13),
#  ('ลื่นไหล', 13),
#  ('แนะนำ', 13),
#  ('เลย#จินยอง', 13),
#  ('#', 13),
#  ('แจบอมอ่', 13),
#  ("'", 10),
#  ('นัก', 9),
#  ('Kafka', 9),
#  ('on', 9),
#  ('Shore', 9),
#  ('(', 8),
#  ('Murakami ', 8),
#  ('Haruki', 8),
#  ('เสพ', 8),
#  ('แนวแบบ', 8),
#  ('อะไร', 8),
#  ('สมัย', 8),
#  ('ค่อย', 8),
#  ('StolenGlances7', 8),
#  ('Haruki Murakami,', 8),
#  ('ขาย', 8),
#  ('มั้ย', 8),
#  ('คะ', 8),
#  ('ฮือออ', 8),
#  ('#จินยอง', 8),
#  ('อมอ่าน', 8),
#  (')', 7),
#  ('Thitichaya_see:', 7),
#  ('นั้น', 7),
#  ('PiggyTN', 7),
#  ('haruki ', 5),
#  ('murakami', 5),
#  ('ยัง', 5),
#  ('รู้สึก', 5),
#  ('โลก', 5),
#  ('แสน', 5),
#  ('กว้างใหญ่', 5),
#  ('ใบ', 5),
#  ('เดียว', 5),
#  ('สามารถ', 5),
#  ('พึ่ง', 5),
#  ('18.', 4),
#  ('SAILEMOONN Kafka', 4),
#  ('On', 4),
#  ('shore', 4),
#  ('ㅡ', 4),
#  ('พี่ทาส', 4),
#  ('แมว', 4),
#  ('เกลียด', 4),
#  ('ฉาก', 4),
#  ('ตรึงใจ', 4),
#  ('orz', 4),
#  ('จำ', 4),
#  ('สนใจ', 4),
#  ('บ้าง', 4),
#  ('ความทรงจำ', 4),
#  ('อบอุ่น', 4),
#  ('ฉีก', 4),
#  ('ฮะรุกิ มุระกะ', 4),
#  (';', 4),
#  ('พยายาม', 3),
#  ('อารมณ์', 3),
#  ('เพียง', 3),
#  ('เรื่องราว', 3),
#  ('ทรงจำ', 3),
#  ('พร้อม', 3),
#  ('ชิ้น', 3),
#  ('@ww9617rap:', 2),
#  ('เพื่อ', 2),
#  ('ต่าง', 2),
#  ('สูญเสีย', 2),
#  ('สำคัญ', 2),
#  ('เสีย', 2),
#  ('โอกาส', 2),
#  ('พลาด', 2),
#  ('Haru', 2),
#  ('อยาก', 2),
#  ('เหมือน', 2),
#  ('อายุ', 2),
#  ('17', 2),
#  ('ชั่ว', 2),
#  ('นิรันดร์', 2),
#  ('MRJISOOXX', 2),
#  ('‣', 2),
#  ('นิยาย', 2),
#  ('หนัง', 2),
#  ('จีซูดู', 2),
#  ('#จีซูอ่าน', 2),
#  ('Carol', 2),
#  ('สัมพันธ์', 2),
#  ('ผู้', 2),
#  ('หญิง', 2),
#  ('สอง', 2),
#  ('&lt', 2),
#  ('แบบ', 2),
#  ('เหมาะ', 2),
#  ('กินขาด', 2),
#  ('ภาพ', 2),
#  ('@JisooHolic_JS', 2),
#  ('อย่า', 1),
#  ('เผา', 1),
#  ('ทิ้ง', 1),
#  ('ฝืนใจ', 1),
#  ('/', 1),
#  ('#AfterPartty', 1),
#  ('ใจลอย', 1),
#  ('หาด', 1),
#  ('ทราย', 1),
#  ('ขาว', 1),
#  ('น้ำ', 1),
#  ('ทะเล', 1),
#  ('สี', 1),
#  ('ฟ้า', 1),
#  ('โปรด', 1),
#  ('@ninkm17', 1),
#  ('ชั้น', 1),
#  ('ไหร่', 1),
#  ('กิ๊ฟท์', 1),
#  ('อ้วนชอบ', 1),
#  ('@mynameistangkwa', 1),
#  ('สำหรับ', 1),
#  ('บาดแผล', 1),
#  ('ลึก', 1),
#  ('เชิง', 1),
#  ('ราคา', 1),
#  ('จ่าย', 1),
#  ('ชำระ', 1),
#  ('เกร็ด', 1),
#  ('ก้าววิ่ง', 1),
#  ('H', 1),
#  ('#LifeisStrange', 1),
#  ('จำกัด', 1),
#  ('กรอบ', 1),
#  ('บาง', 1),
#  ('ที', 1),
#  ('เชื้อ', 1),
#  ('เพลิง', 1),
#  ('เผาไหม้', 1),
#  ('After', 1),
#  ('Dark', 1),
#  ('#JLITWeek ', 1),
#  ('#LifeisStra', 1),
#  ('ทุกข์', 1),
#  ('ทน', 1),
#  ('ปล่อย', 1),
#  ('มือ', 1),
#  ('#Loveis', 1),
#  ('Strange', 1),
#  ('ข้าง', 1),
#  ('ทึ้ง', 1),
#  ('เสี่ยง', 1),
#  ('#LoveisStr', 1),
#  ('KoiiMyria', 1),
#  ('ยาม', 1),
#  ('สดใส', 1),
#  ('กว่า', 1),
#  ('เป็นอยู่', 1),
#  ('ปัจจุบัน', 1),
#  ('บ่อย', 1),
#  ('ครั้ง', 1),
#  ('แม้', 1),
#  ('ซัก', 1),
#  ('บรรทัด', 1),
#  ('เลือน', 1),
#  ('ราง', 1),
#  ('ตก', 1),
#  ('ภาวะ', 1),
#  ('ซึมเศร้า', 1),
#  ('ฆ่า', 1),
#  ('ตลอด', 1),
#  ('&', 1),
#  ('gt', 1),
#  ('@linxuelan', 1),
#  ('ทราบ', 1),
#  ('วิธี', 1),
#  ('ดำรง', 1),
#  ('ใช่', 1),
#  ('ตรงข้าม', 1),
#  ('หาก', 1),
#  ('มุราคามิ', 1),
#  ('นอร์วีเจียน', 1),
#  ('วูด', 1),
#  ('@ballballbule', 1),
#  ('หั', 1),
#  ('13', 1),
#  ('.', 1),
#  ('@psphci', 1),
#  ('ปี', 1),
#  ('1969', 1),
#  ('ผุด', 1),
#  ('ขึ้น', 1),
#  ('ใจ', 1),
#  ('คล้าย', 1),
#  ('บ่อ', 1),
#  ('น้ำพุ', 1),
#  ('ก่อน', 1),
#  ('ดูด', 1),
#  ('รองเท้า', 1),
#  ('จม', 1),
#  ('คราว', 1),
#  ('เหยียบ', 1),
#  ('12yrsoldjj', 1),
#  ('ตาม', 1),
#  ('ลำพัง', 1),
#  ('หรอก', 1),
#  ('ครับ', 1),
#  ('&gt', 1),
#  ('htt', 1)]

# %%
len(counts)
# Out:
# 398

# %%
#Import Thai to English traslator
from googletrans import Translator
translator = Translator()
translator.translate('สวัสดีครับ',dest='en').text
# Out:
# 'Hello'

# %%
#Print words but in english.
for word,count in counts.most_common(400):
    print("('%s',%d)"%(translator.translate(word,dest='en').text,count))
# Out:
# ('Think',1460)
# ('Read',1402)
# ('person',1380)
# ('book',827)
# ('Haruki Murakami',789)
# ('speak',757)
# ('Japanese',660)
# ('if',660)
# ('Quotes',658)
# ('That',658)
# ('Sara update',657)
# ('The',513)
# ('give',510)
# ('day',461)
# ('…',395)
# ('And',371)
# ('—',238)
# ('@readery_co',237)
# ('good',235)
# ('Go',177)
# ('dead',171)
# ('with',168)
# ('love',168)
# ('in',162)
# ('body',160)
# ('Heart',152)
# ('crumble',149)
# ('it',148)
# ('Myself',145)
# ('on',144)
# ('To',142)
# ('You',142)
# ('TPaperless',141)
# ('I',141)
# ('To',140)
# ('when',140)
# ('each',139)
# ('Eye',138)
# ('The next',138)
# ('morning',138)
# ('Bed',138)
# ('sleep',138)
# ('help',138)
# ('wind up',138)
# ('full',138)
# ('tell',138)
# ('with',138)
# ('the best',138)
# ('are',137)
# ('He has',136)
# ('just',127)
# ('subject',118)
# ('many',108)
# (',',107)
# ('any',102)
# ('where',101)
# ('“',101)
# ('”',101)
# ('No matter',100)
# ('Size',100)
# ('open your heart',99)
# ('Straightforward',99)
# ('inevitably',99)
# ('turns on',99)
# ('Mouth',99)
# ('From',98)
# ('real',97)
# ('Come',96)
# ('It',89)
# ('or',86)
# ('until',85)
# ('desire',84)
# ('kind',84)
# ('heal',84)
# ('be sad',84)
# ('guard',84)
# ('look',84)
# ('end',84)
# ('learning',84)
# ('Grueling',83)
# ('Thailand',76)
# ('promise',70)
# ('who',66)
# ('already',61)
# ('Ever',60)
# ('book',56)
# ('but',55)
# ('tattoo',52)
# ('of',49)
# ('norwegian',49)
# ('wood',49)
# ('# Ja',49)
# ('Is',43)
# ('name',43)
# ('enter',42)
# ('ItsView_',41)
# (':',41)
# ('#JJProjcet',41)
# ('keep',41)
# ('List',41)
# ('Come on',41)
# ('P.S.',41)
# ('# Chi',41)
# ('Haruki Murakami-',38)
# ('use',37)
# ('#AfterParty',37)
# ('bowtylight',37)
# ('must',36)
# ('dream',36)
# ('wrong',36)
# ('hope',36)
# ('words',36)
# ('last',36)
# ('disappear',36)
# ('Pinball',36)
# ('1973',36)
# ('#Lifeis',35)
# ('per',35)
# ('@Jinyoung_Books',35)
# ('JB',35)
# ('hold',35)
# ('issue',35)
# ('to translate',35)
# ('Believe',34)
# ('Let's',34)
# ('time',34)
# ('@bowtylight',33)
# ('In',33)
# ('the',32)
# ('Not',30)
# ('call',28)
# ('Music',26)
# ('Any',26)
# ('join',26)
# ('Life',24)
# ('you',22)
# ('Past',21)
# ('that',21)
# ('Return',21)
# ('one',21)
# ('Write',20)
# ('thing',19)
# ('various',19)
# ('move',19)
# ('by',19)
# ('catch',19)
# ('Take',19)
# ('hold',19)
# ('Is it',19)
# ('The way',19)
# ('Hear',19)
# ('Wind',19)
# ('Sing',19)
# ('Dan_TripleP',19)
# ('Time',19)
# ('#Afte',18)
# ('liked it',18)
# ('former',18)
# ('Grumble',18)
# ('Lost secret',18)
# ('cry',18)
# ('stigma',18)
# ('may',18)
# ('Back',18)
# ('night',18)
# ('...',18)
# ('CandideBooks',17)
# ('Norwegian',17)
# ('Wood',17)
# ('part',16)
# ('this',16)
# ('work',16)
# ('Much',15)
# ('Those',14)
# ('at all',14)
# ('know',14)
# ('Hello',13)
# ('stop',13)
# ('listen',13)
# ('sheet',13)
# ('vinyl',13)
# ('Moose',13)
# ('Appear',13)
# ('he',13)
# ('many',13)
# ('I',13)
# ('SunnBlaze',13)
# ('Haruka',13)
# ('Moose',13)
# ('easy',13)
# ('Flow',13)
# ('recommend',13)
# ('# Jin Young',13)
# ('#',13)
# ('Jaebeom',13)
# (''',10)
# ('The',9)
# ('Kafka',9)
# ('on',9)
# ('Shore',9)
# ('(',8)
# ('Murakami',8)
# ('Haruki',8)
# ('Eat',8)
# ('Portrait style',8)
# ('What',8)
# ('period',8)
# ('gradually',8)
# ('StolenGlances7',8)
# ('Haruki Murakami,',8)
# ('Sell',8)
# ('Are you',8)
# ('To me',8)
# ('Hello',8)
# ('# Jin Young',8)
# ('Read',8)
# (')',7)
# ('Thitichaya_see:',7)
# ('that',7)
# ('PiggyTN',7)
# ('haruki',5)
# ('murakami',5)
# ('to',5)
# ('feel',5)
# ('Earth',5)
# ('hundred thousand',5)
# ('vast',5)
# ('blade',5)
# ('one',5)
# ('can',5)
# ('just',5)
# ('18.',4)
# ('SAILEMOONN Kafka',4)
# ('On',4)
# ('shore',4)
# ('ㅡ',4)
# ('Brother Slave',4)
# ('a cat',4)
# ('hate',4)
# ('Scene',4)
# ('Fascinate',4)
# ('barley',4)
# ('remember',4)
# ('interested',4)
# ('some',4)
# ('memory',4)
# ('warm',4)
# ('tear',4)
# ('Haruki muraaka',4)
# (';',4)
# ('attempt',3)
# ('Emotion',3)
# ('Only',3)
# ('a story',3)
# ('memories',3)
# ('ready',3)
# ('Piece',3)
# ('@ ww9617rap:',2)
# ('for',2)
# ('different',2)
# ('lose',2)
# ('important',2)
# ('waste',2)
# ('chance',2)
# ('miss',2)
# ('spring',2)
# ('wanted',2)
# ('as',2)
# ('Age',2)
# ('17',2)
# ('evil',2)
# ('forever',2)
# ('MRJISOOXX',2)
# ('‣',2)
# ('Fiction',2)
# ('movie',2)
# ('Ji Su',2)
# ('# Gdi read',2)
# ('Carol',2)
# ('relationships',2)
# ('person',2)
# ('female',2)
# ('two',2)
# ('&lt',2)
# ('model',2)
# ('Ideal',2)
# ('be superior',2)
# ('Image',2)
# ('@JisooHolic_JS',2)
# ('Do not',1)
# ('burn',1)
# ('leave',1)
# ('force',1)
# ('/',1)
# ('#AfterPartty',1)
# ('distraught',1)
# ('beach',1)
# ('Sand',1)
# ('White',1)
# ('water',1)
# ('sea',1)
# ('color',1)
# ('Blue',1)
# ('please',1)
# ('@ ninkm17',1)
# ('class',1)
# ('How much',1)
# ('Gift',1)
# ('Fat like',1)
# ('@mynameistangkwa',1)
# ('For',1)
# ('wound',1)
# ('Deep',1)
# ('foot',1)
# ('price',1)
# ('Pay',1)
# ('pay',1)
# ('Tips',1)
# ('Run',1)
# ('H',1)
# ('#LifeisStrange',1)
# ('Ltd',1)
# ('frame',1)
# ('some',1)
# ('T',1)
# ('Infection',1)
# ('fire',1)
# ('burn',1)
# ('After',1)
# ('Dark',1)
# ('#JLITWeek',1)
# ('#LifeisStra',1)
# ('Suffering',1)
# ('bear',1)
# ('release',1)
# ('hand',1)
# ('#Seasons',1)
# ('Strange',1)
# ('side',1)
# ('tear',1)
# ('risky',1)
# ('#LoveisStr',1)
# ('Cookies',1)
# ('security guard',1)
# ('bright',1)
# ('than',1)
# ('As is',1)
# ('present',1)
# ('frequent',1)
# ('time',1)
# ('even',1)
# ('wash',1)
# ('Line',1)
# ('fuzzy',1)
# ('rail',1)
# ('fall',1)
# ('condition',1)
# ('depress',1)
# ('the killing',1)
# ('throughout',1)
# ('&',1)
# ('gt',1)
# ('@ Lin Xuelan',1)
# ('know',1)
# ('method',1)
# ('Maintain',1)
# ('Yes',1)
# ('opposite',1)
# ('if',1)
# ('Muhammad',1)
# ('Norwegian',1)
# ('Woodwood',1)
# ('@ballballbule',1)
# ('Pahang',1)
# ('13',1)
# ('.',1)
# ('@ Pascha',1)
# ('year',1)
# ('1969',1)
# ('Pop',1)
# ('up',1)
# ('mind',1)
# ('resemble',1)
# ('depression',1)
# ('the fountain',1)
# ('Before',1)
# ('suck',1)
# ('shoes',1)
# ('sink',1)
# ('time',1)
# ('tread',1)
# ('12yrsoldjj',1)
# ('according',1)
# ('alone',1)
# ('It's',1)
# ('Is offline',1)
# ('&gt',1)
# ('htt',1)
